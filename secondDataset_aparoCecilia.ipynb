# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline

# %%
data = pd.read_csv("MPsProfileInformation10thParliament.csv")
data
# Out:
#      Number                      Name of M.P   District  \
# 0         1               Aadroa Alex Onzima       None
# 1         2                    Ababiku Jesca   Adjumani
# 2         3  ABACANON CHARLES ANGIRO GUTOMOI       Lira
# 3         4                      ABALA DAVID      Ngora
# 4         5             ABBAS AGABA MUGISHA    Kamwenge
# ..      ...                              ...        ...
# 434     435            Wekomba Nambozo Sarah  Bulambuli
# 435     436         Werikhe Kafabusa Michael      Mbale
# 436     437                    Woboya Vicent    Sironko
# 437     438               Yaguma Wilberforce    Mbarara
# 438     439                    Zaake Francis    Mityana
#
#                       Constituency Political Party       Profession  \
# 0                       Ex-Officio            None    Administrator
# 1    District Woman Representative             NRM          Teacher
# 2               ERUTE COUNTY NORTH             FDC           Farmer
# ...

# %%
data.columns
# Out:
# Index(['Number', 'Name of M.P', 'District', 'Constituency', 'Political Party',
#        'Profession', 'Marital status', 'Phone number', 'Date of Birth',
#        'P.L.E School', 'P.L.E Year', 'U.C.E School', 'U.C.E Year',
#        'U.A.C.E School', 'U.A.C.E Year', 'First Degree',
#        'University of First Degree', 'Year of first Degree', 'Second Degree',
#        'University of Second Degree', 'Year of second degree', 'Third Degree',
#        'University of Third Degree', 'Year of Third Degree',
#        'Other Qualifications', 'Past Job_1', 'Past Job_2', 'Past Job_3',
#        'Past Job_4', 'Past Job_5', 'Past Job_6', 'Past Job_7', 'Past Job_8',
#        'Past Job_9', 'Past Job_10', 'Hobbies', 'Special Interests',
#        'Other Information', 'Professional Body Membership', 'Committee_1',
#        'Role on Committee 1', 'Committee_2', 'Role on Committee 2',
#        'Committee_3', 'Role on Committee 3', 'Unnamed: 45', 'Unnamed: 46'],
#       dtype='object')

# %%
data.isnull
# Out:
# <bound method DataFrame.isnull of      Number                      Name of M.P   District  \
# 0         1               Aadroa Alex Onzima       None
# 1         2                    Ababiku Jesca   Adjumani
# 2         3  ABACANON CHARLES ANGIRO GUTOMOI       Lira
# 3         4                      ABALA DAVID      Ngora
# 4         5             ABBAS AGABA MUGISHA    Kamwenge
# ..      ...                              ...        ...
# 434     435            Wekomba Nambozo Sarah  Bulambuli
# 435     436         Werikhe Kafabusa Michael      Mbale
# 436     437                    Woboya Vicent    Sironko
# 437     438               Yaguma Wilberforce    Mbarara
# 438     439                    Zaake Francis    Mityana
#
#                       Constituency Political Party       Profession  \
# 0                       Ex-Officio            None    Administrator
# 1    District Woman Representative             NRM          Teacher
# ...

# %%
data.isnull().any()
# Out:
# Number                          False
# Name of M.P                     False
# District                        False
# Constituency                    False
# Political Party                 False
# Profession                       True
# Marital status                   True
# Phone number                     True
# Date of Birth                    True
# P.L.E School                     True
# P.L.E Year                       True
# U.C.E School                     True
# U.C.E Year                       True
# U.A.C.E School                   True
# U.A.C.E Year                     True
# First Degree                     True
# University of First Degree       True
# Year of first Degree             True
# Second Degree                    True
# University of Second Degree      True
# Year of second degree            True
# Third Degree                     True
# University of Third Degree       True
# Year of Third Degree             True
# Other Qualifications             True
# ...

# %%
data.isnull().sum()
# Out:
# Number                            0
# Name of M.P                       0
# District                          0
# Constituency                      0
# Political Party                   0
# Profession                        1
# Marital status                    3
# Phone number                      6
# Date of Birth                     7
# P.L.E School                    287
# P.L.E Year                      259
# U.C.E School                    157
# U.C.E Year                      107
# U.A.C.E School                  184
# U.A.C.E Year                    136
# First Degree                     82
# University of First Degree       54
# Year of first Degree             60
# Second Degree                   257
# University of Second Degree     251
# Year of second degree           254
# Third Degree                    396
# University of Third Degree      398
# Year of Third Degree            398
# Other Qualifications            146
# Past Job_1                        8
# ...

# %%
new_data= data.fillna(0)
new_data.head()
# Out:
#    Number                      Name of M.P  District  \
# 0       1               Aadroa Alex Onzima      None
# 1       2                    Ababiku Jesca  Adjumani
# 2       3  ABACANON CHARLES ANGIRO GUTOMOI      Lira
# 3       4                      ABALA DAVID     Ngora
# 4       5             ABBAS AGABA MUGISHA   Kamwenge
#
#                     Constituency Political Party       Profession  \
# 0                     Ex-Officio            None    Administrator
# 1  District Woman Representative             NRM          Teacher
# 2             ERUTE COUNTY NORTH             FDC           Farmer
# 3                   Ngora County             NRM    Administrator
# 4              Kitagwenda County             NRM  Lawyer/Advocate
#
#   Marital status            Phone number Date of Birth  \
# 0        Married             0.999914621    06-24-1952
# 1         Single               772315541    07/17/1975
# 2        Married               392944775    05-17-1949
# ...

# %%
new_data["Role on Committee 1"].mode()
# Out:
# 0    Member
# Name: Role on Committee 1, dtype: object

# %%
new_data["Role on Committee 1"].mode()[0]
# Out:
# 'Member'

# %%
new_data1 = new_data["Role on Committee 1"].fillna('Member')
new_data1
# Out:
# 0                     0
# 1                Member
# 2                Member
# 3                Member
# 4      Vice Chairperson
#              ...
# 434              Member
# 435                   0
# 436              Member
# 437              Member
# 438              Member
# Name: Role on Committee 1, Length: 439, dtype: object

# %%
new_data1.head()
# Out:
# 0                   0
# 1              Member
# 2              Member
# 3              Member
# 4    Vice Chairperson
# Name: Role on Committee 1, dtype: object

# %%
new_data["Other Information"].mode()[0]
# Out:
# 0

# %%
#no duplicates
new_data.duplicated().sum()
# Out:
# 0

# %%
fig = px.box(new_data, y="Marital status")

fig.show()
the boxplot below shows some existing outliers in the MARITAL STATUS COLUMN

# %%
fig = px.box(new_data, y= "Political Party")

fig.show()
the boxplot below shows some existing outliers in the MARITAL STATUS COLUMN

# %%
plt.hist("Committee_2")

plt.show()

# %%
#using a correlation matrix

plt.figure(figsize=(100, 80))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9460\2982391797.py in <module>
#       2
#       3 plt.figure(figsize=(100, 80))
# ----> 4 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
#       5
#       6 plt.title('Correlation Matrix')
#
# NameError: name 'correlation_matrix' is not defined
