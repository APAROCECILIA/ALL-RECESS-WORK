# %%
#Introduction to Machine Learning
#Algorithms, Models that help computer to learn and Predict!
#Applications of Machine Learning
# """
# 1. Image Processing
# 2. Speech Recognition
# 3. Fraud detection 

# Approaches to Machine Learning
# 1. Supervised Learning: Dataset that is labelled, predict, Linear Regression,
# decision tree, support vector machine, neural networks 
#  2. Unsupervised Learning: Deals with unlabelled, clustering algorithms to group data together.
#  k-means clustering, hierarchical clustering, PCA(Principal Component Analysis)
#  3. Reinforcement Learning: 

#  # Problem Formulation!
#  1. Define the problem! Classification Task, Regression Analysis, Clustering, Anomaly Detection recommendations.
# 2. Gather the data.
# 3. Split the data.

# Data Types
# 3 Categories of data!
# 1. Numerical! data can be discrete(Integers) or continous(Infinite values)
# 2. 
#  """

# %%
# Check if you have scikit-learn installed
# pip show scikit-learn # check if scikit-learn is installed
#pip install -U scikit-learn

import numpy as np # Linear algebra
import pandas as pd #Data processing, CSV file(pd.read_csv)
import matplotlib.pyplot as plt #plotting/Data visualization
import seaborn as sns # Statistical data visualization
# %matplotlib inline 

#ML for Regression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Control Display! this is optional
pd.options.display.max_columns= 50
sns.set(style= "darkgrid", rc= {'axes.facecolor': 'CAF1DE'})

# Ignore Warnings
import warnings

warnings.filterwarnings('ignore')

# %%
#Load/ Read the dataset
df= pd.read_csv('heart_disease.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
#  _summary_
# cp= chest pain
# trestbps= resting blood pressure
# chol= cholestrol
# fbs= fasting blood sugar
# restecg= resting electrocardiography
# exang= exercise induced agina
# oldpeak= ST depression peak
# slope= the slope of the peak exercise
# ca= number of major vessels
# thal= normal, fexiles defect, reversible defect
# target= have disease or not
#

# %%
# Show NUmber of peoplewith Heart Disease
# Column target

df.target.value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
# Show percetange of male and female
count_female= len(df[df.sex== 0])
count_male= len(df[df.sex== 1])
# Show output
print('Percetange of Female Patients: {:.2f}%'.format(count_female/(len(df.sex)) * 100))
print('Percetange of Male Patients: {:.2f}%'.format(count_male/(len(df.sex)) * 100))
# Out:
# Percetange of Female Patients: 30.44%
# Percetange of Male Patients: 69.56%

# %%
df.groupby('target').mean()
# Out:
#               age       sex        cp    trestbps        chol       fbs  \
# target
# 0       56.569138  0.827655  0.482966  134.106212  251.292585  0.164329
# 1       52.408745  0.570342  1.378327  129.245247  240.979087  0.134981
#
#          restecg     thalach     exang   oldpeak     slope        ca      thal
# target
# 0       0.456914  139.130261  0.549098  1.600200  1.166333  1.158317  2.539078
# 1       0.598859  158.585551  0.134981  0.569962  1.593156  0.370722  2.119772

# %%
#Barplot showing heart disease frequency of age
pd.crosstab(df.age, df.target).plot(kind= 'bar', figsize= (20, 6))
plt.title('Heart Disease Frequency for Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#DataVisualization of Heart Disease Frequency for sex
pd.crosstab(df.sex, df.target).plot(kind= 'bar', figsize= (20, 6), color=['violet', 'green'])
plt.title('Heart Disease Frequency for Sex')
plt.xlabel('Sex')
plt.legend(['Have Diasease', 'Does not have disease'])
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.show()

# %%
#Barplot showing heart disease frequency of age
pd.crosstab(df.age, df.target).plot(kind= 'bar', figsize= (20, 6))
plt.title('Heart Disease Frequency for Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Scatterplot 
age = df['age']
chol = df['chol']

# Create scatter plot
plt.scatter(age, chol, c=df['target'], cmap='coolwarm')
plt.xlabel('age')
plt.ylabel('Cholesterol')
plt.title('Scatter Plot: age vs Cholesterol')
plt.colorbar(label='Target')
plt.show()

# %%
# Working with ML model Accuracy of Different ML More
# Create Model for Logistic Regression
# Solve problems based on classification. Create independent variables and dependent variables
# Categorical prediction!

# %%
# Creating a model for Logistic Regression
y= df.target.values
x_data= df.drop(['target'], axis= 1)

# %%
# Normalise the data! Split our data for training and testing
# 80% training #20% testing
# Normalize the data X= (X- Xmin)/(Xmax-Xmin)
x= (x_data - np.min(x_data)) / (np.max(x_data) - np.min(x_data))

# %%
# Split the data 80% training #20% testing
# x_train, x_test, y_train, y_test= train_test_split(x,y, test_size= 0.3, random_state= 0)

x_train, x_test, y_train, y_test= train_test_split(x,y, test_size= 0.3, random_state= 0)

# Logistic Regression, #testing and Training, Independent variable and dependent variable
# Decision Tree

# %%
# Transpose matrices
x_train= x_train.T
y_train= y_train.T
x_test= x_test.T 
y_test= y_test.T

# %%
# Train and Test in Machine Learning

# Livingstone
#  _summary_
# Linear Regression
# Polynomial Regression
# Multiple Regression
# Scale

# # Jeff
# Train/Test
# Logistic Regression
# Decision Tree
# Confusion Matrix
# Hierarchical Clustering
# Categorical Data
# k-means
# Cross Validation
# AUC- ROC curve
# KNN

# %%
# Machine Learning
# Train and Test
# _summary_

# Training Data
# Independent variables and dependent variables 
# Divide data, x and y
# train_x, test_x, train_y, test_y
# x_train, x_test, y_train, y_test

# Splitting Data
# Divide data in two subsets

# Larger portion testing for training and testing
# 80% of the training and 20% for testing 
# 70, 30
# Evaluate performance ACcuracy 100% !99.87% Accuracy

# Model Testing
# Be specific with the training algorithm(Linear regression, Decision trees, SVM, KNN, etc)

# Model Evaluation
# Evaluation Metrics, Accuracy, Precision, Recall, F1-score, Mean Squared error. Common ways to assess the performance of model
# Performance Assessments
# - Give insight about the performance

# %%
# Import ML libraries
from sklearn.model_selection import train_test_split #Used for splitting the dataset
from sklearn.linear_model import LogisticRegression ##Used for classification problems 
from sklearn.metrics import accuracy_score #Analyse the level of accuracy of the model

#Target data is always the dependent variable which you want to train your model on

# Dataset Let's say you have X to be independent variables(input features) and Y to be dependent variables
# Your target variable
# When dealing with logistic regression, its important to store independent variables in x
# Store dependent variables i (target data) in Y.

# Split Data into training and testing sets

X_train, X_test, y_train, y_test= train_test_split(x, y, test_size= 0.3, random_state= 40)

# Model Training
model= LogisticRegression()
model.fit(X_train, y_train)

# Model Evaluation
y_pred= model.predict(X_test)
accuracy= accuracy_score(y_test, y_pred)

#Display results
print('Accuracy:' , accuracy)
# Out:
# Accuracy: 0.8181818181818182

# %%
from sklearn import linear_model
# Create data using array
X= numpy.array([1, 2, 3, 4]).reshape(-1, 1)
y= numpy.array([0, 0, 1, 1]) # 0 is No, and 1 id Yes

# Model training
logr = linear_model.LogisticRegression()
logr.fit(X, y)

# Model Evaluation
y_pred= logr.predict(numpy.array([3]).reshape(-1, 1))
#accuracy= accuracy_score(numpy.array(y_pred))

# Display result
print(y_pred)
# Out:
# [1]

# %%
# Decision Tree 
# Uses classification and Regression

#  _summary_
# Pros
# - Easy to understand
# - Can handle both regression and classification
# - Captures nonlinear relationships
# - Can handle missing values or outliers

# Cons
# - Prone to overfitting
# - Sensitivity to small changes
# - May not perform well features or noise data

# %%
# Decision tree demonstration
from sklearn.tree import DecisionTreeClassifier

# %%
# Worked Example 1:

# Learn how to set up the Django and flask on your environment
# Web development the Django and web Flask application

# Final

# 1. DS data science
# 2. ML Machine Learning
# 3. WD Web Development
